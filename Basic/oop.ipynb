# %%
class Student:
    def __init__(self,name,usn):
        self.name = name
        self.usn = usn
    
    def disp(self):
        print(self.name)
        print(self.usn)
        
s1 = Student("Husen",455)
print(s1)
s1.disp()
# Out:
# ...
# Husen
# 455
